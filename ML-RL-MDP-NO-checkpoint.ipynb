# %% [markdown]
# ML-RL-task-ev-numbers

# %%
import pandas as pd

# %%
import pandas as pd

data = {
    "Name": ["A", "B", "C"],
    "Marks": [85, 90, None]
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)

df = df.fillna(0)

print("\nAfter filling missing values:")
print(df)
# Out:
# Original DataFrame:
#   Name  Marks
# 0    A   85.0
# 1    B   90.0
# 2    C    NaN
#
# After filling missing values:
#   Name  Marks
# 0    A   85.0
# 1    B   90.0
# 2    C    0.0

# %%
x = 10
x = 20
x
# Out:
# 20
