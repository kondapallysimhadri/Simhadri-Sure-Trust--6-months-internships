# %% [markdown]
# ## Problem 1:

# %% [markdown]
# Transaction Frequency Analyzer

# %%
# Input:
Transactions = [200, 500, 200, 100, 500, 200, 100, 500, 500]

for amount in transactions:
    if amount in frequency:
        frequency[amount] += 1
    else:
        frequency[amount] = 1


sorted_transactions = sorted(
    frequency.items(),
    key=lambda x: (-x[1], x[0])
)

Transactions_2 = [sorted_transactions[0][0], sorted_transactions[1][0]]

print(Transactions_2)
# Out:
# [500, 200]

# %% [markdown]
# ## Problem 2:

# %% [markdown]
# Missing Value Percentage Calculator

# %%
# Input:
data = [10, None, 20, 30, None, None, 40]

total_count = len(data)

missing_count = 0

for value in data:
    if value is None:
        missing_count += 1
        
missing_percentage =(missing_count / total_count) * 100

missing_percentage = round(missing_percentage, 2)

print(missing_percentage)
# Out:
# 42.86
